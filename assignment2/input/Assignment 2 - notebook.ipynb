# %% [markdown]
# # Avazu CTR prediction

# %%
# Import packages and configure notebook
import pandas as pd

# %% [markdown]
# ## Reading the data
#
# This assumes the "train.gz" file is located in "data" folder in the folder where the notebook is.
#
# The file is really big, so it is not recommended to load the full file in memory.
# You can read the files in chunks and apply online learning (see also lecture notes).
# As a start I would recommend to first develop and test your code with a smaller data sample, however don't wait too long to also test (every now and then) if it also works on the full dataset.

# %%
# Reading the file in chunks

reader = pd.read_csv("data/train.gz", compression='gzip', chunksize=1000)

for df_chunk in reader:
    
    # Apply logic on current chunk of data contained in the df_chunk DataFrame
    print(len(df_chunk))

# %%
# Read only a sample of the data (first nrows)

df_sample = pd.read_csv("data/train.gz", compression='gzip', nrows=10000)

df_sample
